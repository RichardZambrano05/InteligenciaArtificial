# %%
import numpy as np
import pandas as pd
print(pd.__version__)

serieData=pd.Series(data=[100,200,300],index=['Juan', 'Pedro', 'Lucas'])
print(serieData)
print('-----------------')
print(serieData['Pedro'])

print(serieData.index)
print('Pedro' in serieData)

myDictionary={'one':pd.Series([100,200,300], index=['Juan', 'Pedro', 'Lucas']),
              'two':pd.Series([11,22,33], index=['Julio', 'Pedro', 'Lucas'])}

# SERIES AND DATAFRAME

df=pd.DataFrame(myDictionary)
print(df)
print('-------------------------------------------------------------------------')
print(df.index)
print(df.columns)

print(df.loc['Pedro'])
print(df.iloc[2])
# Out:
# 2.0.3
# Juan     100
# Pedro    200
# Lucas    300
# dtype: int64
# -----------------
# 200
# Index(['Juan', 'Pedro', 'Lucas'], dtype='object')
# True
#          one   two
# Juan   100.0   NaN
# Julio    NaN  11.0
# Lucas  300.0  33.0
# Pedro  200.0  22.0
# -------------------------------------------------------------------------
# Index(['Juan', 'Julio', 'Lucas', 'Pedro'], dtype='object')
# Index(['one', 'two'], dtype='object')
# one    200.0
# two     22.0
# Name: Pedro, dtype: float64
# one    300.0
# two     33.0
# Name: Lucas, dtype: float64

# %%
import pandas as pd
df=pd.read_csv('/content/ratings.csv')

# %%
df
# Out:
#           userId  movieId  rating     timestamp
# 0              1      296     5.0  1.147880e+09
# 1              1      306     3.5  1.147869e+09
# 2              1      307     5.0  1.147869e+09
# 3              1      665     5.0  1.147879e+09
# 4              1      899     3.5  1.147869e+09
# ...          ...      ...     ...           ...
# 14411641   93309      480     3.0  1.237605e+09
# 14411642   93309      527     5.0  1.237597e+09
# 14411643   93309      588     2.5  1.237603e+09
# 14411644   93309      593     5.0  1.237604e+09
# 14411645   93309      608     5.0           NaN
#
# [14411646 rows x 4 columns]

# %%
df.get(3)

# %%
df.tail(6)
# Out:
#           userId  movieId  rating     timestamp
# 14411640   93309      474     4.0  1.237605e+09
# 14411641   93309      480     3.0  1.237605e+09
# 14411642   93309      527     5.0  1.237597e+09
# 14411643   93309      588     2.5  1.237603e+09
# 14411644   93309      593     5.0  1.237604e+09
# 14411645   93309      608     5.0           NaN

# %%
del df['timestamp']

# %%
df
# Out:
#           userId  movieId  rating
# 0              1      296     5.0
# 1              1      306     3.5
# 2              1      307     5.0
# 3              1      665     5.0
# 4              1      899     3.5
# ...          ...      ...     ...
# 14411641   93309      480     3.0
# 14411642   93309      527     5.0
# 14411643   93309      588     2.5
# 14411644   93309      593     5.0
# 14411645   93309      608     5.0
#
# [14411646 rows x 3 columns]

# %%
df.shape
# Out:
# (14411646, 3)

# %%
df.columns
# Out:
# Index(['userId', 'movieId', 'rating'], dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=14411646, step=1)

# %%
tmp=df.iloc[4]

# %%
tmp
# Out:
# userId       1.0
# movieId    899.0
# rating       3.5
# Name: 4, dtype: float64

# %%
tmp['userId']
# Out:
# 1.0

# %%
'rating' in df.columns
# Out:
# True

# %%
df.iloc[[100,200,300]]
# Out:
#      userId  movieId  rating
# 100       2     1080     1.0
# 200       2     4886     5.0
# 300       3     1320     3.5

# %%
df.describe()
# Out:
#              userId       movieId        rating
# count  1.441165e+07  1.441165e+07  1.441165e+07
# mean   4.685211e+04  2.153808e+04  3.531920e+00
# std    2.684576e+04  3.944881e+04  1.061518e+00
# min    1.000000e+00  1.000000e+00  5.000000e-01
# 25%    2.376300e+04  1.197000e+03  3.000000e+00
# 50%    4.669400e+04  2.951000e+03  3.500000e+00
# 75%    7.013700e+04  8.636000e+03  4.000000e+00
# max    9.330900e+04  2.091630e+05  5.000000e+00

# %%
min_rating = df['rating'].min()
max_rating = df['rating'].max()
mean_rating = df['rating'].mean()

print("Minimum rating:", min_rating)
print("Maximum rating:", max_rating)
print("Average rating:", mean_rating)
# Out:
# Minimum rating: 0.5
# Maximum rating: 5.0
# Average rating: 3.531920295572067

# %%
movies=pd.read_csv('/content/movies.csv')
tags=pd.read_csv('/content/tags.csv')
ratings=pd.read_csv('/content/ratings.csv')

# %%
movies.head(2)
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
tags.head(2)
# Out:
#    userId  movieId      tag   timestamp
# 0       3      260  classic  1439472355
# 1       3      260   sci-fi  1439472256

# %%
ratings.head(2)
# Out:
#    userId  movieId  rating   timestamp
# 0       1      296     5.0  1147880044
# 1       1      306     3.5  1147868817

# %%
del ratings['timestamp']
del tags['timestamp']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3652         try:
# -> 3653             return self._engine.get_loc(casted_key)
#    3654         except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'timestamp'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-62-3528c63a9b7a> in <cell line: 1>()
# ----> 1 del ratings['timestamp']
#       2 del tags['timestamp']
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in __delitem__(self, key)
#    4277             # there was no match, this call should raise the appropriate
#    4278             # exception:
# -> 4279             loc = self.axes[-1].get_loc(key)
#    4280             self._mgr = self._mgr.idelete(loc)
#    4281
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3653             return self._engine.get_loc(casted_key)
#    3654         except KeyError as err:
# -> 3655             raise KeyError(key) from err
#    3656         except TypeError:
#    3657             # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'timestamp'

# %%
print(movies.shape)
print(tags.shape)
print(ratings.shape)
# Out:
# (62423, 3)
# (1093360, 3)
# (25000095, 3)

# %%
movies.isnull().any()
# Out:
# movieId    False
# title      False
# genres     False
# dtype: bool

# %%
tags.isnull().any()
# Out:
# userId     False
# movieId    False
# tag         True
# dtype: bool

# %%
ratings.isnull().any()
# Out:
# userId     False
# movieId    False
# rating     False
# dtype: bool

# %%
print(tags.shape)
aux1=tags.shape[0]
tags=tags.dropna()
aux2=tags.shape[0]
print(tags.shape)
print(aux1)
print(tags.shape)
print(f'Se eliminaron {aux1-aux2} registros')
# Out:
# (1093344, 3)
# (1093344, 3)
# 1093344
# (1093344, 3)
# Se eliminaron 0 registros

# %%
print(ratings.columns)
print(ratings['rating'].max())
print(f'Numero de muestras antes del filtro {ratings.shape[0]}')
print(ratings['rating'].min())
calificacion_alta=ratings['rating']>=4

# %%
ratings_despues=ratings[calificacion_alta]
print('Numero de muestras despues del filtro',ratings_despues.shape)
